# %%
import numpy as np
import matplotlib.pyplot as plt 
train_losses = np.load('train_losses.npy')
test_losses = np.load('valid_losses.npy')

plt.plot(train_losses, 'b', label='train-loss')
plt.plot(test_losses, 'r', label='test-loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
